# %%
import httpx 
import json

# There exists multiple implementations of jsonpath for Python, not all of them have the ability to filter. 
# Some implementations throw an error if you try to use a filter funcitonallity within JSON path

from jsonpath_ng.ext import parser

# %%
 
# Opening JSON file
f = open('data/most_recent_objects.json')
# returns JSON object as 
# a dictionary
members = json.load(f)  
# Closing file
f.close()

# %%
# a smaller dataset to work with
url = "https://apidg.gent.be/opendata/adlib2eventstream/v1/stam/objecten"
members = httpx.get(url,follow_redirects=True).json()

# %%
# member - get digital object
digital_objects = parser.parse('$..["Entiteit.isHetOnderwerpVan"][?(@.["@type"]=="DigitalObject")][@id]').find(members)
urls = len([x.value for x in digital_objects])

# %%
print(json.dumps(members,indent=4))
# Out:
# {
#     "@context": {
#         "prov": "http://www.w3.org/ns/prov#",
#         "tree": "https://w3id.org/tree#",
#         "sh": "http://www.w3.org/ns/shacl#",
#         "dcterms": "http://purl.org/dc/terms/",
#         "tree:member": {
#             "@type": "@id"
#         },
#         "memberOf": {
#             "@reverse": "tree:member",
#             "@type": "@id"
#         },
#         "tree:node": {
#             "@type": "@id"
#         },
#         "tree:path": {
#             "@type": "@id"
#         },
#         "viewOf": {
#             "@reverse": "tree:view",
#             "@type": "@id"
#         }
#     },
#     "@id": "https://apidg.gent.be/opendata/adlib2eventstream/v1/stam/objecten?generatedAtTime=2023-04-03T00:03:10.193Z",
#     "@type": "tree:Node",
#     "viewOf": {
#         "@id": "https://stad.gent/id/dataset/stam/34ee0269ec5b7dc6fb6e8f98a16a2664",
#         "@type": "tree:Collection"
#     },
#     "@included": [
#         {
#             "@context": [
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-object-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/persoon-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-event-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/organisatie-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/generiek-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/dossier.jsonld",
#                 {
#                     "dcterms:isVersionOf": {
#                         "@type": "@id"
#                     },
#                     "prov": "http://www.w3.org/ns/prov#",
#                     "skos": "http://www.w3.org/2004/02/skos/core#",
#                     "label": "http://www.w3.org/2000/01/rdf-schema#label",
#                     "opmerking": "http://www.w3.org/2004/02/skos/core#note",
#                     "foaf": "http://xmlns.com/foaf/0.1/",
#                     "foaf:page": {
#                         "@type": "@id"
#                     },
#                     "cest": "https://www.projectcest.be/wiki/Publicatie:Invulboek_objecten/Veld/",
#                     "inhoud": "http://www.cidoc-crm.org/cidoc-crm/P190_has_symbolic_content",
#                     "la": "https://linked.art/ns/terms/",
#                     "conforms_to": {
#                         "@id": "dcterms:conformsTo",
#                         "@type": "@id",
#                         "@container": "@set"
#                     },
#                     "equivalent": {
#                         "@id": "la:equivalent",
#                         "@type": "@id"
#                     },
#                     "dig": "http://www.ics.forth.gr/isl/CRMdig/",
#                     "DigitalObject": {
#                         "@id": "dig:D1_Digital_Object"
#                     },
#                     "kwalificatie": {
#                         "@id": "http://purl.org/ontology/af/confidence"
#                     }
#                 }
#             ],
#             "@id": "https://stad.gent/id/mensgemaaktobject/stam/550000678/2023-04-03T00:03:10.193Z",
#             "@type": "MensgemaaktObject",
#             "dcterms:isVersionOf": "https://stad.gent/id/mensgemaaktobject/stam/550000678",
#             "prov:generatedAtTime": "2023-04-03T00:03:10.193Z",
#             "foaf:page": "https://stad.gent/data/mensgemaaktobject/stam/550000678/2023-04-03T00:03:10.193Z",
#             "Object.identificator": [
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "550000678",
#                         "@type": "https://stad.gent/id/identificatiesysteem/priref"
#                     }
#                 },
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "11352",
#                         "@type": "https://stad.gent/id/identificatiesysteem/objectnummer"
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Waarde_objectnummer",
#                         "label": "objectnummer"
#                     }
#                 }
#             ],
#             "MaterieelDing.beheerder": "http://www.wikidata.org/entity/Q980285",
#             "Entiteit.classificatie": [
#                 {
#                     "@type": "Classificatie",
#                     "Classificatie.getypeerdeEntiteit": "https://stad.gent/id/mensgemaaktobject/stam/550000678",
#                     "Classificatie.toegekendType": {
#                         "@id": "http://vocab.getty.edu/aat/300209904",
#                         "skos:prefLabel": {
#                             "@value": "vest (kleding)",
#                             "@language": "nl"
#                         }
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Term_objectnaam",
#                         "label": "objectnaam"
#                     }
#                 }
#             ],
#             "MensgemaaktObject.titel": {
#                 "@value": "Vest (avondkledij)",
#                 "@language": "nl"
#             },
#             "Entiteit.beschrijving": {
#                 "@value": "Het korte vest heeft een diepe V-vormige halsuitsnijding belegd met een naar onder verbredende sjaalkraag en horizontale basis. Een sluiting midden voor met vijf met weefsel beklede knopen en knoopsgaten. Smalle horizontaal geplaatste zakkleppen met drie punten en in de rug wordt de vest aangepast met twee banden, een knoop (nu ontbrekend) en knoopsgat.\r\nHet weefselpatroon bestaat uit verspringende horizontale rijen met bloemtakjes en gezaaide gestileerde bloempjes op de achtergrond.",
#                 "@language": "nl"
#             },
#             "MaterieelDing.productie": [
#                 {
#                     "@type": "Productie",
#                     "Gebeurtenis.tijd": {
#                         "@value": "1830/1840",
#                         "@type": "http://id.loc.gov/datatypes/edtf/EDTF"
#                     },
#                     "Productie.product": "https://stad.gent/id/mensgemaaktobject/stam/550000678",
#                     "Activiteit.uitgevoerdDoor": {
#                         "@type": "Agent",
#                         "equivalent": {
#                             "@id": "https://stad.gent/id/agent/550020738",
#                             "@type": "Agent",
#                             "label": {
#                                 "@value": "onbekend",
#                                 "@language": "nl"
#                             }
#                         },
#                         "Entiteit.type": {
#                             "@id": "cest:Naam_vervaardiger",
#                             "label": "vervaardiger"
#                         }
#                     },
#                     "Gebeurtenis.plaats": {
#                         "@type": "Plaats",
#                         "equivalent": {
#                             "@id": "https://stad.gent/id/concept/550000114",
#                             "skos:prefLabel": {
#                                 "@value": "onbekend",
#                                 "@language": "nl"
#                             }
#                         },
#                         "Entiteit.type": {
#                             "@id": "cest:Naam_plaats_vervaardiging",
#                             "label": "vervaardiging.plaats"
#                         }
#                     }
#                 }
#             ],
#             "MensgemaaktObject.draagt": {
#                 "@type": "InformatieObject",
#                 "InformatieObject.drager": "https://stad.gent/id/mensgemaaktobject/stam/550000678",
#                 "InformatieObject.verwijstNaar": [],
#                 "InformatieObject.gaatOver": []
#             },
#             "MensgemaaktObject.beeldtUit": [],
#             "MensgemaaktObject.materiaal": [
#                 {
#                     "@type": "TypeMateriaal",
#                     "Entiteit.type": [
#                         {
#                             "@id": "http://vocab.getty.edu/aat/300231565",
#                             "skos:prefLabel": {
#                                 "@value": "textiel (materiaal)",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_materials",
#                             "label": "materiaal"
#                         }
#                     ]
#                 },
#                 {
#                     "@type": "TypeMateriaal",
#                     "Entiteit.type": [
#                         {
#                             "@id": "http://vocab.getty.edu/aat/300183670",
#                             "skos:prefLabel": {
#                                 "@value": "katoen",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_materials",
#                             "label": "materiaal"
#                         }
#                     ]
#                 }
#             ],
#             "MensgemaaktObject.dimensie": [
#                 {
#                     "@type": "Dimensie",
#                     "Dimensie.beschrijving": "Dimensie van geheel",
#                     "Dimensie.type": "hoogte",
#                     "Dimensie.waarde": "50",
#                     "Dimensie.eenheid": "cm"
#                 },
#                 {
#                     "@type": "Dimensie",
#                     "Dimensie.beschrijving": "Dimensie van geheel",
#                     "Dimensie.type": "breedte",
#                     "Dimensie.waarde": "40",
#                     "Dimensie.eenheid": "cm"
#                 }
#             ],
#             "MaterieelDing.isOvergedragenBijVerwerving": {
#                 "@type": "Verwerving",
#                 "Activiteit.gebruikteTechniek": {
#                     "@type": "TypeTechniek",
#                     "Entiteit.type": [
#                         {
#                             "@id": "https://stad.gent/id/concept/550000114",
#                             "skos:prefLabel": {
#                                 "@value": "onbekend",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_verwervingsmethode",
#                             "label": "verwerving.methode"
#                         }
#                     ]
#                 },
#                 "Verwerving.overdrachtVan": "https://stad.gent/id/mensgemaaktobject/stam/550000678",
#                 "Verwerving.overgedragenAan": "http://www.wikidata.org/entity/Q980285"
#             },
#             "Entiteit.maaktDeelUitVan": [
#                 {
#                     "@type": "Collectie",
#                     "Activiteit.gebruiktObject": {
#                         "@type": "Activiteit",
#                         "Entiteit.type": "http://vocab.getty.edu/aat/300054766",
#                         "Entiteit.beschrijving": {
#                             "@value": "Textilia Kostuums en accessoires uit eigen bezit",
#                             "@language": "nl"
#                         },
#                         "Gebeurtenis.tijd": {
#                             "@value": "1986-07-10/1986-08-31",
#                             "@type": "http://id.loc.gov/datatypes/edtf/EDTF"
#                         }
#                     }
#                 }
#             ],
#             "Entiteit.isHetOnderwerpVan": [
#                 {
#                     "@id": "https://api.collectie.gent/iiif/presentation/v2/manifest/stam:11352",
#                     "@type": "DigitalObject",
#                     "conforms_to": [
#                         {
#                             "@id": "https://iiif.io/api/presentation",
#                             "@type": "InformatieObject"
#                         }
#                     ],
#                     "format": "application/ld+json;profile=\\\"http://iiif.io/api/presentation/2/context.json\\\""
#                 }
#             ],
#             "memberOf": "https://stad.gent/id/dataset/stam/34ee0269ec5b7dc6fb6e8f98a16a2664"
#         },
#         {
#             "@context": [
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-object-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/persoon-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-event-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/organisatie-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/generiek-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/dossier.jsonld",
#                 {
#                     "dcterms:isVersionOf": {
#                         "@type": "@id"
#                     },
#                     "prov": "http://www.w3.org/ns/prov#",
#                     "skos": "http://www.w3.org/2004/02/skos/core#",
#                     "label": "http://www.w3.org/2000/01/rdf-schema#label",
#                     "opmerking": "http://www.w3.org/2004/02/skos/core#note",
#                     "foaf": "http://xmlns.com/foaf/0.1/",
#                     "foaf:page": {
#                         "@type": "@id"
#                     },
#                     "cest": "https://www.projectcest.be/wiki/Publicatie:Invulboek_objecten/Veld/",
#                     "inhoud": "http://www.cidoc-crm.org/cidoc-crm/P190_has_symbolic_content",
#                     "la": "https://linked.art/ns/terms/",
#                     "conforms_to": {
#                         "@id": "dcterms:conformsTo",
#                         "@type": "@id",
#                         "@container": "@set"
#                     },
#                     "equivalent": {
#                         "@id": "la:equivalent",
#                         "@type": "@id"
#                     },
#                     "dig": "http://www.ics.forth.gr/isl/CRMdig/",
#                     "DigitalObject": {
#                         "@id": "dig:D1_Digital_Object"
#                     },
#                     "kwalificatie": {
#                         "@id": "http://purl.org/ontology/af/confidence"
#                     }
#                 }
#             ],
#             "@id": "https://stad.gent/id/mensgemaaktobject/stam/550000724/2023-04-03T00:03:15.194Z",
#             "@type": "MensgemaaktObject",
#             "dcterms:isVersionOf": "https://stad.gent/id/mensgemaaktobject/stam/550000724",
#             "prov:generatedAtTime": "2023-04-03T00:03:15.194Z",
#             "foaf:page": "https://stad.gent/data/mensgemaaktobject/stam/550000724/2023-04-03T00:03:15.194Z",
#             "Object.identificator": [
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "550000724",
#                         "@type": "https://stad.gent/id/identificatiesysteem/priref"
#                     }
#                 },
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "10243",
#                         "@type": "https://stad.gent/id/identificatiesysteem/objectnummer"
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Waarde_objectnummer",
#                         "label": "objectnummer"
#                     }
#                 }
#             ],
#             "MaterieelDing.beheerder": "http://www.wikidata.org/entity/Q980285",
#             "Entiteit.classificatie": [
#                 {
#                     "@type": "Classificatie",
#                     "Classificatie.getypeerdeEntiteit": "https://stad.gent/id/mensgemaaktobject/stam/550000724",
#                     "Classificatie.toegekendType": {
#                         "@id": "http://vocab.getty.edu/aat/300046143",
#                         "skos:prefLabel": {
#                             "@value": "jas",
#                             "@language": "nl"
#                         }
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Term_objectnaam",
#                         "label": "objectnaam"
#                     }
#                 }
#             ],
#             "MensgemaaktObject.titel": {
#                 "@value": "Jas",
#                 "@language": "nl"
#             },
#             "Entiteit.beschrijving": {
#                 "@value": "De jas van bruin-rood gesneden zijdefluweel heeft een ronde hals, voorpanden met rechte zijranden die vanaf de heupen tamelijk uitstaan en op de rug vanaf de heupen vormt de middennaad naar beneden toe een split. De panden overlappen er elkaar, twee plooien flankeren de split. Ook de zijnaden hebben een split en vormen twee plooien over dezelfde hoogte. Lange mouwen, twee zakken met klep met drie punten en een mouwomslag met drie knopen en onder de zakopening vier knopen. Langs de rand van het rechtervoorpand heeft de jas acht knopen. De koperen knopen zijn tweedelig: een licht bol gestampt voorplaatje met een vlechtwerkpatroon en een achterplaatje met oogje (vermoedelijk 19de eeuws).\r\nDe jas is belegd met verguld zilvergalon langs de zijranden van de voorpanden, langs de mouwomslagen en de zakkleppen. Gestileerde bloemtakjes en vruchttakjes op linnen geborduurd zijn geappliqueerd op de jas, langs de randen van de voorpanden, acht laddersgewijs, drie op de mouwomslagen, vier op de zakkleppen en vier op de rug in de lenden.\r\nOp de voering staat een stempel, vermoedelijk van een kostuumverhuringsfirma,  met omslag \"Maison Moreau - D. Baron Successeur - R. de filles St. Thomas 7\". vermoedelijk betreft het hier een kostuumverhuringsfirma.",
#                 "@language": "nl"
#             },
#             "MaterieelDing.productie": [
#                 {
#                     "@type": "Productie",
#                     "Gebeurtenis.tijd": {
#                         "@value": "1750~/1750~",
#                         "@type": "http://id.loc.gov/datatypes/edtf/EDTF"
#                     },
#                     "Productie.product": "https://stad.gent/id/mensgemaaktobject/stam/550000724",
#                     "Activiteit.uitgevoerdDoor": {
#                         "@type": "Agent",
#                         "equivalent": {
#                             "@id": "https://stad.gent/id/agent/550020957",
#                             "@type": "Agent",
#                             "label": {
#                                 "@value": "Maison Moreau",
#                                 "@language": "nl"
#                             }
#                         },
#                         "Entiteit.type": {
#                             "@id": "cest:Naam_vervaardiger",
#                             "label": "vervaardiger"
#                         }
#                     },
#                     "Gebeurtenis.plaats": {
#                         "@type": "Plaats",
#                         "equivalent": {
#                             "@id": "http://vocab.getty.edu/tgn/7008038",
#                             "skos:prefLabel": {
#                                 "@value": "Parijs",
#                                 "@language": "nl"
#                             }
#                         },
#                         "Entiteit.type": {
#                             "@id": "cest:Naam_plaats_vervaardiging",
#                             "label": "vervaardiging.plaats"
#                         }
#                     }
#                 }
#             ],
#             "MensgemaaktObject.draagt": {
#                 "@type": "InformatieObject",
#                 "InformatieObject.drager": "https://stad.gent/id/mensgemaaktobject/stam/550000724",
#                 "InformatieObject.verwijstNaar": [],
#                 "InformatieObject.gaatOver": []
#             },
#             "MensgemaaktObject.beeldtUit": [],
#             "MensgemaaktObject.materiaal": [
#                 {
#                     "@type": "TypeMateriaal",
#                     "Entiteit.type": [
#                         {
#                             "@id": "http://vocab.getty.edu/aat/300243428",
#                             "skos:prefLabel": {
#                                 "@value": "zijde (textiel)",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_materials",
#                             "label": "materiaal"
#                         }
#                     ]
#                 },
#                 {
#                     "@type": "TypeMateriaal",
#                     "Entiteit.type": [
#                         {
#                             "@id": "http://vocab.getty.edu/aat/300395639",
#                             "skos:prefLabel": {
#                                 "@value": "zilverdraad",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_materials",
#                             "label": "materiaal"
#                         }
#                     ]
#                 }
#             ],
#             "MensgemaaktObject.dimensie": [
#                 {
#                     "@type": "Dimensie",
#                     "Dimensie.beschrijving": "Dimensie van geheel",
#                     "Dimensie.type": "hoogte",
#                     "Dimensie.waarde": "101",
#                     "Dimensie.eenheid": "cm"
#                 },
#                 {
#                     "@type": "Dimensie",
#                     "Dimensie.beschrijving": "Dimensie van geheel",
#                     "Dimensie.type": "breedte",
#                     "Dimensie.waarde": "59",
#                     "Dimensie.eenheid": "cm"
#                 },
#                 {
#                     "@type": "Dimensie",
#                     "Dimensie.beschrijving": "Dimensie van geheel",
#                     "Dimensie.type": "breedte",
#                     "Dimensie.waarde": "36",
#                     "Dimensie.eenheid": "cm"
#                 }
#             ],
#             "MaterieelDing.bestaatUit": [
#                 {
#                     "@type": "MaterieelDing",
#                     "Entiteit.beschrijving": "jas",
#                     "MensgemaaktObject.materiaal": [
#                         {
#                             "@type": "TypeMateriaal",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "cest:Term_materiaal",
#                                     "label": "materiaal"
#                                 },
#                                 {
#                                     "@id": "http://vocab.getty.edu/aat/300133711",
#                                     "skos:prefLabel": {
#                                         "@value": "fluweel",
#                                         "@language": "nl"
#                                     }
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "@type": "MaterieelDing",
#                     "Entiteit.beschrijving": "voering",
#                     "MensgemaaktObject.materiaal": [
#                         {
#                             "@type": "TypeMateriaal",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "cest:Term_materiaal",
#                                     "label": "materiaal"
#                                 },
#                                 {
#                                     "@id": "http://vocab.getty.edu/aat/300243428",
#                                     "skos:prefLabel": {
#                                         "@value": "zijde (textiel)",
#                                         "@language": "nl"
#                                     }
#                                 }
#                             ]
#                         },
#                         {
#                             "@type": "TypeMateriaal",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "cest:Term_materiaal",
#                                     "label": "materiaal"
#                                 },
#                                 {
#                                     "@id": "http://vocab.getty.edu/aat/300014069",
#                                     "skos:prefLabel": {
#                                         "@value": "linnen",
#                                         "@language": "nl"
#                                     }
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "@type": "MaterieelDing",
#                     "Entiteit.beschrijving": "knopen",
#                     "MensgemaaktObject.materiaal": [
#                         {
#                             "@type": "TypeMateriaal",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "cest:Term_materiaal",
#                                     "label": "materiaal"
#                                 },
#                                 {
#                                     "@id": "http://vocab.getty.edu/aat/300010946",
#                                     "skos:prefLabel": {
#                                         "@value": "messing",
#                                         "@language": "nl"
#                                     }
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "MaterieelDing.isOvergedragenBijVerwerving": {
#                 "@type": "Verwerving",
#                 "Gebeurtenis.tijd": {
#                     "@type": "Periode",
#                     "Periode.begin": "1897-12-29",
#                     "Periode.einde": "1897-12-29"
#                 },
#                 "Activiteit.gebruikteTechniek": {
#                     "@type": "TypeTechniek",
#                     "Entiteit.type": [
#                         {
#                             "@id": "https://stad.gent/id/concept/550005834",
#                             "skos:prefLabel": {
#                                 "@value": "aankoop",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_verwervingsmethode",
#                             "label": "verwerving.methode"
#                         }
#                     ]
#                 },
#                 "Gebeurtenis.plaats": {
#                     "@type": "Locatie",
#                     "Entiteit.type": [
#                         {
#                             "@id": "http://vocab.getty.edu/tgn/7007868",
#                             "skos:prefLabel": {
#                                 "@value": "Brussel",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Plaats_verwervingsbron",
#                             "label": "verwerving.plaats"
#                         }
#                     ]
#                 },
#                 "Verwerving.overdrachtVan": "https://stad.gent/id/mensgemaaktobject/stam/550000724",
#                 "Verwerving.overgedragenAan": "http://www.wikidata.org/entity/Q980285"
#             },
#             "Entiteit.maaktDeelUitVan": [
#                 {
#                     "@type": "Collectie",
#                     "Activiteit.gebruiktObject": {
#                         "@type": "Activiteit",
#                         "Entiteit.type": "http://vocab.getty.edu/aat/300054766",
#                         "Entiteit.beschrijving": {
#                             "@value": "Textilia Kostuums en accessoires uit eigen bezit",
#                             "@language": "nl"
#                         },
#                         "Gebeurtenis.tijd": {
#                             "@value": "1986-07-10/1986-08-31",
#                             "@type": "http://id.loc.gov/datatypes/edtf/EDTF"
#                         }
#                     }
#                 }
#             ],
#             "Entiteit.isHetOnderwerpVan": [
#                 {
#                     "@id": "https://api.collectie.gent/iiif/presentation/v2/manifest/stam:10243",
#                     "@type": "DigitalObject",
#                     "conforms_to": [
#                         {
#                             "@id": "https://iiif.io/api/presentation",
#                             "@type": "InformatieObject"
#                         }
#                     ],
#                     "format": "application/ld+json;profile=\\\"http://iiif.io/api/presentation/2/context.json\\\""
#                 }
#             ],
#             "memberOf": "https://stad.gent/id/dataset/stam/34ee0269ec5b7dc6fb6e8f98a16a2664"
#         },
#         {
#             "@context": [
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-object-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/persoon-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-event-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/organisatie-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/generiek-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/dossier.jsonld",
#                 {
#                     "dcterms:isVersionOf": {
#                         "@type": "@id"
#                     },
#                     "prov": "http://www.w3.org/ns/prov#",
#                     "skos": "http://www.w3.org/2004/02/skos/core#",
#                     "label": "http://www.w3.org/2000/01/rdf-schema#label",
#                     "opmerking": "http://www.w3.org/2004/02/skos/core#note",
#                     "foaf": "http://xmlns.com/foaf/0.1/",
#                     "foaf:page": {
#                         "@type": "@id"
#                     },
#                     "cest": "https://www.projectcest.be/wiki/Publicatie:Invulboek_objecten/Veld/",
#                     "inhoud": "http://www.cidoc-crm.org/cidoc-crm/P190_has_symbolic_content",
#                     "la": "https://linked.art/ns/terms/",
#                     "conforms_to": {
#                         "@id": "dcterms:conformsTo",
#                         "@type": "@id",
#                         "@container": "@set"
#                     },
#                     "equivalent": {
#                         "@id": "la:equivalent",
#                         "@type": "@id"
#                     },
#                     "dig": "http://www.ics.forth.gr/isl/CRMdig/",
#                     "DigitalObject": {
#                         "@id": "dig:D1_Digital_Object"
#                     },
#                     "kwalificatie": {
#                         "@id": "http://purl.org/ontology/af/confidence"
#                     }
#                 }
#             ],
#             "@id": "https://stad.gent/id/mensgemaaktobject/stam/550000778/2023-04-03T00:03:20.195Z",
#             "@type": "MensgemaaktObject",
#             "dcterms:isVersionOf": "https://stad.gent/id/mensgemaaktobject/stam/550000778",
#             "prov:generatedAtTime": "2023-04-03T00:03:20.195Z",
#             "foaf:page": "https://stad.gent/data/mensgemaaktobject/stam/550000778/2023-04-03T00:03:20.195Z",
#             "Object.identificator": [
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "550000778",
#                         "@type": "https://stad.gent/id/identificatiesysteem/priref"
#                     }
#                 },
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "11412",
#                         "@type": "https://stad.gent/id/identificatiesysteem/objectnummer"
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Waarde_objectnummer",
#                         "label": "objectnummer"
#                     }
#                 }
#             ],
#             "MaterieelDing.beheerder": "http://www.wikidata.org/entity/Q980285",
#             "Entiteit.classificatie": [
#                 {
#                     "@type": "Classificatie",
#                     "Classificatie.getypeerdeEntiteit": "https://stad.gent/id/mensgemaaktobject/stam/550000778",
#                     "Classificatie.toegekendType": {
#                         "@id": "http://vocab.getty.edu/aat/300209935",
#                         "skos:prefLabel": {
#                             "@value": "broek",
#                             "@language": "nl"
#                         }
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Term_objectnaam",
#                         "label": "objectnaam"
#                     }
#                 }
#             ],
#             "MensgemaaktObject.titel": {
#                 "@value": "Knie- of kuitbroek",
#                 "@language": "nl"
#             },
#             "Entiteit.beschrijving": {
#                 "@value": "Broek in gebrocheerde liser\u00e9-rips met een grote horizontale klep bevestigd met drie knopen en knoopsgaten tegen een tailleband, over een vertikale sluiting met drie knopen en knoopsgaten op de tailleband, waar  midden op de rug een split die met drie doorgeregen veters dichtgeknoopt wordt. De knopen zijn bekleed met het weefsel. Op de broek, onder de rechterklephoek: een zak. Het weefsel is in de rug tegen de tailleband gefronseld. Onderaan de kuitlange pjjpen langs de buitennaad: een splitje (ongewoon als afwerking van de pijpen in de 18de eeuw).\r\nEen weefselpatroon  van kruisende golvende takken en bloemtakken vormen golvende lijnen.",
#                 "@language": "nl"
#             },
#             "MaterieelDing.productie": [
#                 {
#                     "@type": "Productie",
#                     "Gebeurtenis.tijd": {
#                         "@value": "1755/1765",
#                         "@type": "http://id.loc.gov/datatypes/edtf/EDTF"
#                     },
#                     "Productie.product": "https://stad.gent/id/mensgemaaktobject/stam/550000778",
#                     "Activiteit.gebruikteTechniek": [
#                         {
#                             "@type": "TypeTechniek",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "https://stad.gent/id/concept/550008415",
#                                     "skos:prefLabel": {
#                                         "@value": "lisere",
#                                         "@language": "nl"
#                                     }
#                                 },
#                                 {
#                                     "@id": "cest:Term_techniek",
#                                     "label": "techniek"
#                                 }
#                             ]
#                         },
#                         {
#                             "@type": "TypeTechniek",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "http://vocab.getty.edu/aat/300417856",
#                                     "skos:prefLabel": {
#                                         "@value": "ripsbinding",
#                                         "@language": "nl"
#                                     }
#                                 },
#                                 {
#                                     "@id": "cest:Term_techniek",
#                                     "label": "techniek"
#                                 }
#                             ]
#                         }
#                     ],
#                     "Activiteit.uitgevoerdDoor": {
#                         "@type": "Agent",
#                         "equivalent": {
#                             "@id": "https://stad.gent/id/agent/550020738",
#                             "@type": "Agent",
#                             "label": {
#                                 "@value": "onbekend",
#                                 "@language": "nl"
#                             }
#                         },
#                         "Entiteit.type": {
#                             "@id": "cest:Naam_vervaardiger",
#                             "label": "vervaardiger"
#                         }
#                     },
#                     "Gebeurtenis.plaats": {
#                         "@type": "Plaats",
#                         "equivalent": {
#                             "@id": "https://stad.gent/id/concept/550000114",
#                             "skos:prefLabel": {
#                                 "@value": "onbekend",
#                                 "@language": "nl"
#                             }
#                         },
#                         "Entiteit.type": {
#                             "@id": "cest:Naam_plaats_vervaardiging",
#                             "label": "vervaardiging.plaats"
#                         }
#                     }
#                 }
#             ],
#             "MensgemaaktObject.draagt": {
#                 "@type": "InformatieObject",
#                 "InformatieObject.drager": "https://stad.gent/id/mensgemaaktobject/stam/550000778",
#                 "InformatieObject.verwijstNaar": [],
#                 "InformatieObject.gaatOver": []
#             },
#             "MensgemaaktObject.beeldtUit": [],
#             "MensgemaaktObject.materiaal": [
#                 {
#                     "@type": "TypeMateriaal",
#                     "Entiteit.type": [
#                         {
#                             "@id": "http://vocab.getty.edu/aat/300162391",
#                             "skos:prefLabel": {
#                                 "@value": "stof (textiel)",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_materials",
#                             "label": "materiaal"
#                         }
#                     ]
#                 }
#             ],
#             "MensgemaaktObject.dimensie": [
#                 {
#                     "@type": "Dimensie",
#                     "Dimensie.beschrijving": "Dimensie van geheel",
#                     "Dimensie.type": "hoogte",
#                     "Dimensie.waarde": "121",
#                     "Dimensie.eenheid": "cm"
#                 },
#                 {
#                     "@type": "Dimensie",
#                     "Dimensie.beschrijving": "Dimensie van geheel",
#                     "Dimensie.type": "breedte",
#                     "Dimensie.waarde": "42",
#                     "Dimensie.eenheid": "cm"
#                 }
#             ],
#             "MaterieelDing.bestaatUit": [
#                 {
#                     "@type": "MaterieelDing",
#                     "Entiteit.beschrijving": "voering",
#                     "MensgemaaktObject.materiaal": [
#                         {
#                             "@type": "TypeMateriaal",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "cest:Term_materiaal",
#                                     "label": "materiaal"
#                                 },
#                                 {
#                                     "@id": "http://vocab.getty.edu/aat/300014069",
#                                     "skos:prefLabel": {
#                                         "@value": "linnen",
#                                         "@language": "nl"
#                                     }
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "MaterieelDing.isOvergedragenBijVerwerving": {
#                 "@type": "Verwerving",
#                 "Activiteit.gebruikteTechniek": {
#                     "@type": "TypeTechniek",
#                     "Entiteit.type": [
#                         {
#                             "@id": "https://stad.gent/id/concept/550000114",
#                             "skos:prefLabel": {
#                                 "@value": "onbekend",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_verwervingsmethode",
#                             "label": "verwerving.methode"
#                         }
#                     ]
#                 },
#                 "Verwerving.overdrachtVan": "https://stad.gent/id/mensgemaaktobject/stam/550000778",
#                 "Verwerving.overgedragenAan": "http://www.wikidata.org/entity/Q980285"
#             },
#             "Entiteit.maaktDeelUitVan": [
#                 {
#                     "@type": "Collectie",
#                     "Activiteit.gebruiktObject": {
#                         "@type": "Activiteit",
#                         "Entiteit.type": "http://vocab.getty.edu/aat/300054766",
#                         "Entiteit.beschrijving": {
#                             "@value": "Textilia Kostuums en accessoires uit eigen bezit",
#                             "@language": "nl"
#                         },
#                         "Gebeurtenis.tijd": {
#                             "@value": "1986-07-10/1986-08-31",
#                             "@type": "http://id.loc.gov/datatypes/edtf/EDTF"
#                         }
#                     }
#                 }
#             ],
#             "Entiteit.isHetOnderwerpVan": [
#                 {
#                     "@id": "https://api.collectie.gent/iiif/presentation/v2/manifest/stam:11412",
#                     "@type": "DigitalObject",
#                     "conforms_to": [
#                         {
#                             "@id": "https://iiif.io/api/presentation",
#                             "@type": "InformatieObject"
#                         }
#                     ],
#                     "format": "application/ld+json;profile=\\\"http://iiif.io/api/presentation/2/context.json\\\""
#                 }
#             ],
#             "memberOf": "https://stad.gent/id/dataset/stam/34ee0269ec5b7dc6fb6e8f98a16a2664"
#         },
#         {
#             "@context": [
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-object-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/persoon-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-event-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/organisatie-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/generiek-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/dossier.jsonld",
#                 {
#                     "dcterms:isVersionOf": {
#                         "@type": "@id"
#                     },
#                     "prov": "http://www.w3.org/ns/prov#",
#                     "skos": "http://www.w3.org/2004/02/skos/core#",
#                     "label": "http://www.w3.org/2000/01/rdf-schema#label",
#                     "opmerking": "http://www.w3.org/2004/02/skos/core#note",
#                     "foaf": "http://xmlns.com/foaf/0.1/",
#                     "foaf:page": {
#                         "@type": "@id"
#                     },
#                     "cest": "https://www.projectcest.be/wiki/Publicatie:Invulboek_objecten/Veld/",
#                     "inhoud": "http://www.cidoc-crm.org/cidoc-crm/P190_has_symbolic_content",
#                     "la": "https://linked.art/ns/terms/",
#                     "conforms_to": {
#                         "@id": "dcterms:conformsTo",
#                         "@type": "@id",
#                         "@container": "@set"
#                     },
#                     "equivalent": {
#                         "@id": "la:equivalent",
#                         "@type": "@id"
#                     },
#                     "dig": "http://www.ics.forth.gr/isl/CRMdig/",
#                     "DigitalObject": {
#                         "@id": "dig:D1_Digital_Object"
#                     },
#                     "kwalificatie": {
#                         "@id": "http://purl.org/ontology/af/confidence"
#                     }
#                 }
#             ],
#             "@id": "https://stad.gent/id/mensgemaaktobject/stam/550000994/2023-04-03T00:03:25.196Z",
#             "@type": "MensgemaaktObject",
#             "dcterms:isVersionOf": "https://stad.gent/id/mensgemaaktobject/stam/550000994",
#             "prov:generatedAtTime": "2023-04-03T00:03:25.196Z",
#             "foaf:page": "https://stad.gent/data/mensgemaaktobject/stam/550000994/2023-04-03T00:03:25.196Z",
#             "Object.identificator": [
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "550000994",
#                         "@type": "https://stad.gent/id/identificatiesysteem/priref"
#                     }
#                 },
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "11405",
#                         "@type": "https://stad.gent/id/identificatiesysteem/objectnummer"
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Waarde_objectnummer",
#                         "label": "objectnummer"
#                     }
#                 }
#             ],
#             "MaterieelDing.beheerder": "http://www.wikidata.org/entity/Q980285",
#             "Entiteit.classificatie": [
#                 {
#                     "@type": "Classificatie",
#                     "Classificatie.getypeerdeEntiteit": "https://stad.gent/id/mensgemaaktobject/stam/550000994",
#                     "Classificatie.toegekendType": {
#                         "@id": "http://vocab.getty.edu/aat/300209904",
#                         "skos:prefLabel": {
#                             "@value": "vest (kleding)",
#                             "@language": "nl"
#                         }
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Term_objectnaam",
#                         "label": "objectnaam"
#                     }
#                 }
#             ],
#             "MensgemaaktObject.titel": {
#                 "@value": "Vest",
#                 "@language": "nl"
#             },
#             "Entiteit.beschrijving": {
#                 "@value": "Kort vest in vaal lindegroene keperwol met een horizontale basis, een smal staand bandje rond de hals en brede revers, en in de rug wordt de vest aangesloten door twee maal twee linten. Een sluiting midden voor met een dubbele rij van zes knopen en langs de rand van beide voorpanden staan telkens zes knoopsgaten en knopen: vijf knopen van tombak (18de eeuw, \u00e9\u00e9n met een machinaal gegraveerd stermotiefje), zeven verguld koperen knopen (19de eeuw, opschrift op de keerzijde \"supereinf\").\r\nDe voorpanden zijn gesneden uit een geborduurd weefsel (mogelijk hergebruikt) in een patroon van verspringende horizontale rijen -die om de vier rijen in eenzelfde volgorde terugkomen-  met anemoontakjes, afwisselend op- en neerwaarts gericht en gezaaide siermotieven.\r\n",
#                 "@language": "nl"
#             },
#             "MaterieelDing.productie": [
#                 {
#                     "@type": "Productie",
#                     "Gebeurtenis.tijd": {
#                         "@value": "1790/1799",
#                         "@type": "http://id.loc.gov/datatypes/edtf/EDTF"
# ...
#                                         "@value": "hout",
#                                         "@language": "nl"
#                                     }
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "MaterieelDing.isOvergedragenBijVerwerving": {
#                 "@type": "Verwerving",
#                 "Gebeurtenis.tijd": {
#                     "@type": "Periode",
#                     "Periode.begin": "1864",
#                     "Periode.einde": "1864"
#                 },
#                 "Activiteit.gebruikteTechniek": {
#                     "@type": "TypeTechniek",
#                     "Entiteit.type": [
#                         {
#                             "@id": "https://stad.gent/id/concept/550005834",
#                             "skos:prefLabel": {
#                                 "@value": "aankoop",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_verwervingsmethode",
#                             "label": "verwerving.methode"
#                         }
#                     ]
#                 },
#                 "Gebeurtenis.plaats": {
#                     "@type": "Locatie",
#                     "Entiteit.type": [
#                         {
#                             "@id": "http://vocab.getty.edu/tgn/7007887",
#                             "skos:prefLabel": {
#                                 "@value": "Gent",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Plaats_verwervingsbron",
#                             "label": "verwerving.plaats"
#                         }
#                     ]
#                 },
#                 "Verwerving.overdrachtVan": "https://stad.gent/id/mensgemaaktobject/stam/550031872",
#                 "Verwerving.overgedragenAan": "http://www.wikidata.org/entity/Q980285"
#             },
#             "Entiteit.isHetOnderwerpVan": [
#                 {
#                     "@id": "https://api.collectie.gent/iiif/presentation/v2/manifest/stam:14537.092",
#                     "@type": "DigitalObject",
#                     "conforms_to": [
#                         {
#                             "@id": "https://iiif.io/api/presentation",
#                             "@type": "InformatieObject"
#                         }
#                     ],
#                     "format": "application/ld+json;profile=\\\"http://iiif.io/api/presentation/2/context.json\\\""
#                 }
#             ],
#             "memberOf": "https://stad.gent/id/dataset/stam/34ee0269ec5b7dc6fb6e8f98a16a2664"
#         },
#         {
#             "@context": [
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-object-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/persoon-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-event-ap.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/organisatie-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/generiek-basis.jsonld",
#                 "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/dossier.jsonld",
#                 {
#                     "dcterms:isVersionOf": {
#                         "@type": "@id"
#                     },
#                     "prov": "http://www.w3.org/ns/prov#",
#                     "skos": "http://www.w3.org/2004/02/skos/core#",
#                     "label": "http://www.w3.org/2000/01/rdf-schema#label",
#                     "opmerking": "http://www.w3.org/2004/02/skos/core#note",
#                     "foaf": "http://xmlns.com/foaf/0.1/",
#                     "foaf:page": {
#                         "@type": "@id"
#                     },
#                     "cest": "https://www.projectcest.be/wiki/Publicatie:Invulboek_objecten/Veld/",
#                     "inhoud": "http://www.cidoc-crm.org/cidoc-crm/P190_has_symbolic_content",
#                     "la": "https://linked.art/ns/terms/",
#                     "conforms_to": {
#                         "@id": "dcterms:conformsTo",
#                         "@type": "@id",
#                         "@container": "@set"
#                     },
#                     "equivalent": {
#                         "@id": "la:equivalent",
#                         "@type": "@id"
#                     },
#                     "dig": "http://www.ics.forth.gr/isl/CRMdig/",
#                     "DigitalObject": {
#                         "@id": "dig:D1_Digital_Object"
#                     },
#                     "kwalificatie": {
#                         "@id": "http://purl.org/ontology/af/confidence"
#                     }
#                 }
#             ],
#             "@id": "https://stad.gent/id/mensgemaaktobject/stam/550031873/2023-04-03T00:12:23.871Z",
#             "@type": "MensgemaaktObject",
#             "dcterms:isVersionOf": "https://stad.gent/id/mensgemaaktobject/stam/550031873",
#             "prov:generatedAtTime": "2023-04-03T00:12:23.871Z",
#             "foaf:page": "https://stad.gent/data/mensgemaaktobject/stam/550031873/2023-04-03T00:12:23.871Z",
#             "Object.identificator": [
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "550031873",
#                         "@type": "https://stad.gent/id/identificatiesysteem/priref"
#                     }
#                 },
#                 {
#                     "@type": "Identificator",
#                     "Identificator.identificator": {
#                         "@value": "14537.093",
#                         "@type": "https://stad.gent/id/identificatiesysteem/objectnummer"
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Waarde_objectnummer",
#                         "label": "objectnummer"
#                     }
#                 }
#             ],
#             "MaterieelDing.beheerder": "http://www.wikidata.org/entity/Q980285",
#             "Entiteit.classificatie": [
#                 {
#                     "@type": "Classificatie",
#                     "Classificatie.getypeerdeEntiteit": "https://stad.gent/id/mensgemaaktobject/stam/550031873",
#                     "Classificatie.toegekendType": {
#                         "@id": "http://vocab.getty.edu/aat/300047090",
#                         "skos:prefLabel": {
#                             "@value": "beeldhouwwerk",
#                             "@language": "nl"
#                         }
#                     },
#                     "Entiteit.type": {
#                         "@id": "cest:Term_objectnaam",
#                         "label": "objectnaam"
#                     }
#                 }
#             ],
#             "MensgemaaktObject.titel": {
#                 "@value": "Beeldje in koperlegering",
#                 "@language": "nl"
#             },
#             "Entiteit.beschrijving": {
#                 "@value": "Bronzen beeldje met een houten sokkeltje van een naakte man (huisgod?) die op \u00e9\u00e9n voet steunt. Het onderste stuk van het andere been is verdwenen. De achterzijde van het bronzen beeldje vertoont een uitstekend staafje waarmee het beeldje ergens aan kon bevestigd worden. Houten sokkeltje hoort mogelijk niet bij het beeldje.",
#                 "@language": "nl"
#             },
#             "MaterieelDing.productie": [
#                 {
#                     "@type": "Productie",
#                     "Gebeurtenis.tijd": {
#                         "@value": "..",
#                         "@type": "http://id.loc.gov/datatypes/edtf/EDTF"
#                     },
#                     "Productie.product": "https://stad.gent/id/mensgemaaktobject/stam/550031873",
#                     "Activiteit.gebruikteTechniek": [
#                         {
#                             "@type": "TypeTechniek",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "http://vocab.getty.edu/aat/300054038",
#                                     "skos:prefLabel": {
#                                         "@value": "gieten",
#                                         "@language": "nl"
#                                     }
#                                 },
#                                 {
#                                     "@id": "cest:Term_techniek",
#                                     "label": "techniek"
#                                 }
#                             ]
#                         }
#                     ],
#                     "Activiteit.uitgevoerdDoor": {
#                         "@type": "Agent",
#                         "equivalent": {
#                             "@id": "https://stad.gent/id/agent/550020738",
#                             "@type": "Agent",
#                             "label": {
#                                 "@value": "onbekend",
#                                 "@language": "nl"
#                             }
#                         },
#                         "Entiteit.type": {
#                             "@id": "cest:Naam_vervaardiger",
#                             "label": "vervaardiger"
#                         }
#                     },
#                     "Gebeurtenis.plaats": {
#                         "@type": "Plaats",
#                         "equivalent": {
#                             "@id": "https://stad.gent/id/concept/550000114",
#                             "skos:prefLabel": {
#                                 "@value": "onbekend",
#                                 "@language": "nl"
#                             }
#                         },
#                         "Entiteit.type": {
#                             "@id": "cest:Naam_plaats_vervaardiging",
#                             "label": "vervaardiging.plaats"
#                         }
#                     }
#                 }
#             ],
#             "MensgemaaktObject.draagt": {
#                 "@type": "InformatieObject",
#                 "InformatieObject.drager": "https://stad.gent/id/mensgemaaktobject/stam/550031873",
#                 "InformatieObject.verwijstNaar": [],
#                 "InformatieObject.gaatOver": []
#             },
#             "MensgemaaktObject.beeldtUit": [],
#             "MensgemaaktObject.materiaal": [],
#             "MensgemaaktObject.dimensie": [
#                 {
#                     "@type": "Dimensie",
#                     "Dimensie.beschrijving": "Dimensie van geheel",
#                     "Dimensie.type": "hoogte",
#                     "Dimensie.waarde": "8.2",
#                     "Dimensie.eenheid": "cm"
#                 },
#                 {
#                     "@type": "Dimensie",
#                     "Dimensie.beschrijving": "Dimensie van geheel",
#                     "Dimensie.type": "diameter",
#                     "Dimensie.waarde": "3.5",
#                     "Dimensie.eenheid": "cm"
#                 }
#             ],
#             "MaterieelDing.bestaatUit": [
#                 {
#                     "@type": "MaterieelDing",
#                     "Entiteit.beschrijving": "beeld",
#                     "MensgemaaktObject.materiaal": [
#                         {
#                             "@type": "TypeMateriaal",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "cest:Term_materiaal",
#                                     "label": "materiaal"
#                                 },
#                                 {
#                                     "@id": "http://vocab.getty.edu/aat/300010942",
#                                     "skos:prefLabel": {
#                                         "@value": "koperlegering",
#                                         "@language": "nl"
#                                     }
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "@type": "MaterieelDing",
#                     "Entiteit.beschrijving": "sokkel",
#                     "MensgemaaktObject.materiaal": [
#                         {
#                             "@type": "TypeMateriaal",
#                             "Entiteit.type": [
#                                 {
#                                     "@id": "cest:Term_materiaal",
#                                     "label": "materiaal"
#                                 },
#                                 {
#                                     "@id": "http://vocab.getty.edu/aat/300011914",
#                                     "skos:prefLabel": {
#                                         "@value": "hout",
#                                         "@language": "nl"
#                                     }
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "MaterieelDing.isOvergedragenBijVerwerving": {
#                 "@type": "Verwerving",
#                 "Gebeurtenis.tijd": {
#                     "@type": "Periode",
#                     "Periode.begin": "1864",
#                     "Periode.einde": "1864"
#                 },
#                 "Activiteit.gebruikteTechniek": {
#                     "@type": "TypeTechniek",
#                     "Entiteit.type": [
#                         {
#                             "@id": "https://stad.gent/id/concept/550005834",
#                             "skos:prefLabel": {
#                                 "@value": "aankoop",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Term_verwervingsmethode",
#                             "label": "verwerving.methode"
#                         }
#                     ]
#                 },
#                 "Gebeurtenis.plaats": {
#                     "@type": "Locatie",
#                     "Entiteit.type": [
#                         {
#                             "@id": "http://vocab.getty.edu/tgn/7007887",
#                             "skos:prefLabel": {
#                                 "@value": "Gent",
#                                 "@language": "nl"
#                             }
#                         },
#                         {
#                             "@id": "cest:Plaats_verwervingsbron",
#                             "label": "verwerving.plaats"
#                         }
#                     ]
#                 },
#                 "Verwerving.overdrachtVan": "https://stad.gent/id/mensgemaaktobject/stam/550031873",
#                 "Verwerving.overgedragenAan": "http://www.wikidata.org/entity/Q980285"
#             },
#             "Entiteit.isHetOnderwerpVan": [
#                 {
#                     "@id": "https://api.collectie.gent/iiif/presentation/v2/manifest/stam:14537.093",
#                     "@type": "DigitalObject",
#                     "conforms_to": [
#                         {
#                             "@id": "https://iiif.io/api/presentation",
#                             "@type": "InformatieObject"
#                         }
#                     ],
#                     "format": "application/ld+json;profile=\\\"http://iiif.io/api/presentation/2/context.json\\\""
#                 }
#             ],
#             "memberOf": "https://stad.gent/id/dataset/stam/34ee0269ec5b7dc6fb6e8f98a16a2664"
#         }
#     ],
#     "tree:relation": [
#         {
#             "@type": "tree:LessThanRelation",
#             "tree:node": "https://apidg.gent.be/opendata/adlib2eventstream/v1/stam/objecten?generatedAtTime=2023-03-22T00:05:23.262Z",
#             "tree:path": "prov:generatedAtTime",
#             "tree:value": "2023-04-03T00:03:10.193Z",
#             "tree:remainingItems": 41500
#         }
#     ]
# }

# %%
# member - get objects from a specific context
context = "https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-object-ap.jsonld"
selection_of_members = parser.parse(f'$..["@included"][*][@context][?(@=="{context}")].`parent`.`parent`').find(members)
selection = [x.value for x in selection_of_members]
selection[0]
# Out:
# {'@context': ['https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-object-ap.jsonld',
#   'https://apidg.gent.be/opendata/adlib2eventstream/v1/context/persoon-basis.jsonld',
#   'https://apidg.gent.be/opendata/adlib2eventstream/v1/context/cultureel-erfgoed-event-ap.jsonld',
#   'https://apidg.gent.be/opendata/adlib2eventstream/v1/context/organisatie-basis.jsonld',
#   'https://apidg.gent.be/opendata/adlib2eventstream/v1/context/generiek-basis.jsonld',
#   'https://apidg.gent.be/opendata/adlib2eventstream/v1/context/dossier.jsonld',
#   {'dcterms:isVersionOf': {'@type': '@id'},
#    'prov': 'http://www.w3.org/ns/prov#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'label': 'http://www.w3.org/2000/01/rdf-schema#label',
#    'opmerking': 'http://www.w3.org/2004/02/skos/core#note',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'foaf:page': {'@type': '@id'},
#    'cest': 'https://www.projectcest.be/wiki/Publicatie:Invulboek_objecten/Veld/',
#    'inhoud': 'http://www.cidoc-crm.org/cidoc-crm/P190_has_symbolic_content',
#    'la': 'https://linked.art/ns/terms/',
#    'conforms_to': {'@id': 'dcterms:conformsTo',
#     '@type': '@id',
#     '@container': '@set'},
#    'equivalent': {'@id': 'la:equivalent', '@type': '@id'},
#    'dig': 'http://www.ics.forth.gr/isl/CRMdig/',
#    'DigitalObject': {'@id': 'dig:D1_Digital_Object'},
#    'kwalificatie': {'@id': 'http://purl.org/ontology/af/confidence'}}],
#  '@id': 'https://stad.gent/id/mensgemaaktobject/stam/550000678/2023-04-03T00:03:10.193Z',
#  '@type': 'MensgemaaktObject',
#  'dcterms:isVersionOf': 'https://stad.gent/id/mensgemaaktobject/stam/550000678',
#  'prov:generatedAtTime': '2023-04-03T00:03:10.193Z',
#  'foaf:page': 'https://stad.gent/data/mensgemaaktobject/stam/550000678/2023-04-03T00:03:10.193Z',
#  'Object.identificator': [{'@type': 'Identificator',
#    'Identificator.identificator': {'@value': '550000678',
#     '@type': 'https://stad.gent/id/identificatiesysteem/priref'}},
#   {'@type': 'Identificator',
#    'Identificator.identificator': {'@value': '11352',
#     '@type': 'https://stad.gent/id/identificatiesysteem/objectnummer'},
#    'Entiteit.type': {'@id': 'cest:Waarde_objectnummer',
#     'label': 'objectnummer'}}],
#  'MaterieelDing.beheerder': 'http://www.wikidata.org/entity/Q980285',
#  'Entiteit.classificatie': [{'@type': 'Classificatie',
#    'Classificatie.getypeerdeEntiteit': 'https://stad.gent/id/mensgemaaktobject/stam/550000678',
#    'Classificatie.toegekendType': {'@id': 'http://vocab.getty.edu/aat/300209904',
#     'skos:prefLabel': {'@value': 'vest (kleding)', '@language': 'nl'}},
#    'Entiteit.type': {'@id': 'cest:Term_objectnaam', 'label': 'objectnaam'}}],
#  'MensgemaaktObject.titel': {'@value': 'Vest (avondkledij)',
#   '@language': 'nl'},
#  'Entiteit.beschrijving': {'@value': 'Het korte vest heeft een diepe V-vormige halsuitsnijding belegd met een naar onder verbredende sjaalkraag en horizontale basis. Een sluiting midden voor met vijf met weefsel beklede knopen en knoopsgaten. Smalle horizontaal geplaatste zakkleppen met drie punten en in de rug wordt de vest aangepast met twee banden, een knoop (nu ontbrekend) en knoopsgat.\r\nHet weefselpatroon bestaat uit verspringende horizontale rijen met bloemtakjes en gezaaide gestileerde bloempjes op de achtergrond.',
#   '@language': 'nl'},
#  'MaterieelDing.productie': [{'@type': 'Productie',
#    'Gebeurtenis.tijd': {'@value': '1830/1840',
#     '@type': 'http://id.loc.gov/datatypes/edtf/EDTF'},
#    'Productie.product': 'https://stad.gent/id/mensgemaaktobject/stam/550000678',
#    'Activiteit.uitgevoerdDoor': {'@type': 'Agent',
#     'equivalent': {'@id': 'https://stad.gent/id/agent/550020738',
#      '@type': 'Agent',
#      'label': {'@value': 'onbekend', '@language': 'nl'}},
#     'Entiteit.type': {'@id': 'cest:Naam_vervaardiger',
#      'label': 'vervaardiger'}},
#    'Gebeurtenis.plaats': {'@type': 'Plaats',
#     'equivalent': {'@id': 'https://stad.gent/id/concept/550000114',
#      'skos:prefLabel': {'@value': 'onbekend', '@language': 'nl'}},
#     'Entiteit.type': {'@id': 'cest:Naam_plaats_vervaardiging',
#      'label': 'vervaardiging.plaats'}}}],
#  'MensgemaaktObject.draagt': {'@type': 'InformatieObject',
#   'InformatieObject.drager': 'https://stad.gent/id/mensgemaaktobject/stam/550000678',
#   'InformatieObject.verwijstNaar': [],
#   'InformatieObject.gaatOver': []},
#  'MensgemaaktObject.beeldtUit': [],
#  'MensgemaaktObject.materiaal': [{'@type': 'TypeMateriaal',
#    'Entiteit.type': [{'@id': 'http://vocab.getty.edu/aat/300231565',
#      'skos:prefLabel': {'@value': 'textiel (materiaal)', '@language': 'nl'}},
#     {'@id': 'cest:Term_materials', 'label': 'materiaal'}]},
#   {'@type': 'TypeMateriaal',
#    'Entiteit.type': [{'@id': 'http://vocab.getty.edu/aat/300183670',
#      'skos:prefLabel': {'@value': 'katoen', '@language': 'nl'}},
#     {'@id': 'cest:Term_materials', 'label': 'materiaal'}]}],
#  'MensgemaaktObject.dimensie': [{'@type': 'Dimensie',
#    'Dimensie.beschrijving': 'Dimensie van geheel',
#    'Dimensie.type': 'hoogte',
#    'Dimensie.waarde': '50',
#    'Dimensie.eenheid': 'cm'},
#   {'@type': 'Dimensie',
#    'Dimensie.beschrijving': 'Dimensie van geheel',
#    'Dimensie.type': 'breedte',
#    'Dimensie.waarde': '40',
#    'Dimensie.eenheid': 'cm'}],
#  'MaterieelDing.isOvergedragenBijVerwerving': {'@type': 'Verwerving',
#   'Activiteit.gebruikteTechniek': {'@type': 'TypeTechniek',
#    'Entiteit.type': [{'@id': 'https://stad.gent/id/concept/550000114',
#      'skos:prefLabel': {'@value': 'onbekend', '@language': 'nl'}},
#     {'@id': 'cest:Term_verwervingsmethode', 'label': 'verwerving.methode'}]},
#   'Verwerving.overdrachtVan': 'https://stad.gent/id/mensgemaaktobject/stam/550000678',
#   'Verwerving.overgedragenAan': 'http://www.wikidata.org/entity/Q980285'},
#  'Entiteit.maaktDeelUitVan': [{'@type': 'Collectie',
#    'Activiteit.gebruiktObject': {'@type': 'Activiteit',
#     'Entiteit.type': 'http://vocab.getty.edu/aat/300054766',
#     'Entiteit.beschrijving': {'@value': 'Textilia Kostuums en accessoires uit eigen bezit',
#      '@language': 'nl'},
#     'Gebeurtenis.tijd': {'@value': '1986-07-10/1986-08-31',
#      '@type': 'http://id.loc.gov/datatypes/edtf/EDTF'}}}],
#  'Entiteit.isHetOnderwerpVan': [{'@id': 'https://api.collectie.gent/iiif/presentation/v2/manifest/stam:11352',
#    '@type': 'DigitalObject',
#    'conforms_to': [{'@id': 'https://iiif.io/api/presentation',
#      '@type': 'InformatieObject'}],
#    'format': 'application/ld+json;profile=\\"http://iiif.io/api/presentation/2/context.json\\"'}],
#  'memberOf': 'https://stad.gent/id/dataset/stam/34ee0269ec5b7dc6fb6e8f98a16a2664'}
